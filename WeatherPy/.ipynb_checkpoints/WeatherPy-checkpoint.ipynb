# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 598

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = f'https://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}'

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f'https://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}&units=metric'
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | waitangi
# Processing Record 2 of Set 1 | felanitx
# Processing Record 3 of Set 1 | bredasdorp
# Processing Record 4 of Set 1 | port-aux-francais
# Processing Record 5 of Set 1 | tiksi
# Processing Record 6 of Set 1 | saipan
# Processing Record 7 of Set 1 | edinburgh of the seven seas
# Processing Record 8 of Set 1 | broken hill
# Processing Record 9 of Set 1 | petropavlovsk-kamchatsky
# Processing Record 10 of Set 1 | aasiaat
# Processing Record 11 of Set 1 | talnakh
# Processing Record 12 of Set 1 | auki
# Processing Record 13 of Set 1 | atafu village
# Processing Record 14 of Set 1 | adamstown
# Processing Record 15 of Set 1 | fale old settlement
# Processing Record 16 of Set 1 | manokwari
# Processing Record 17 of Set 1 | flying fish cove
# Processing Record 18 of Set 1 | kariba
# Processing Record 19 of Set 1 | isafjordur
# Processing Record 20 of Set 1 | nova olinda do norte
# Processing Record 21 of Set 1 | blackmans bay
# Processing Record 22 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 23 of Set 1 | tura
# Processing Record 24 of Set 1 | lebu
# Processing Record 25 of Set 1 | avarua
# Processing Record 26 of Set 1 | port alfred
# Processing Record 27 of Set 1 | miyaly
# Processing Record 28 of Set 1 | college
# Processing Record 29 of Set 1 | chantada
# Processing Record 30 of Set 1 | pangkalanbuun
# Processing Record 31 of Set 1 | kujang-up
# Processing Record 32 of Set 1 | klyuchi
# Processing Record 33 of Set 1 | touros
# Processing Record 34 of Set 1 | el gouna
# Processing Record 35 of Set 1 | yellowknife
# Processing Record 36 of Set 1 | necochea
# Processing Record 37 of Set 1 | walvis bay
# Processing Record 38 of Set 1 | puerto deseado
# Processing Record 39 of Set 1 | praia da vitoria
# Processing Record 40 of Set 1 | kapa'a
# Processing Record 41 of Set 1 | papatowai
# Processing Record 42 of Set 1 | katsuura
# Processing Record 43 of Set 1 | grytviken
# Processing Record 44 of Set 1 | egilsstadir
# Processing Record 45 of Set 1 | margaret river
# Processing Record 46 of Set 1 | zhanibek
# Processing Record 47 of Set 1 | pontianak
# Processing Record 48 of Set 1 | georgetown
# Processing Record 49 of Set 1 | new norfolk
# Processing Record 50 of Set 1 | iqaluit
# Processing Record 0 of Set 2 | albany
# Processing Record 1 of Set 2 | hirara
# Processing Record 2 of Set 2 | sitka
# Processing Record 3 of Set 2 | jiangyou
# Processing Record 4 of Set 2 | brisas de zicatela
# Processing Record 5 of Set 2 | longyearbyen
# Processing Record 6 of Set 2 | thunder bay
# Processing Record 7 of Set 2 | mata-utu
# Processing Record 8 of Set 2 | jamestown
# Processing Record 9 of Set 2 | harstad
# Processing Record 10 of Set 2 | lihue
# Processing Record 11 of Set 2 | zhongshan
# Processing Record 12 of Set 2 | casa grande
# Processing Record 13 of Set 2 | mount isa
# Processing Record 14 of Set 2 | kazalinsk
# City not found. Skipping...
# Processing Record 15 of Set 2 | cable beach
# City not found. Skipping...
# Processing Record 16 of Set 2 | cambria
# Processing Record 17 of Set 2 | invercargill
# Processing Record 18 of Set 2 | alice springs
# Processing Record 19 of Set 2 | port lincoln
# Processing Record 20 of Set 2 | abraham's bay
# City not found. Skipping...
# Processing Record 21 of Set 2 | remire-montjoly
# Processing Record 22 of Set 2 | pandan
# Processing Record 23 of Set 2 | olonkinbyen
# Processing Record 44 of Set 3 | vernon
# Processing Record 45 of Set 3 | hawaiian paradise park
# Processing Record 46 of Set 3 | morant bay
# Processing Record 47 of Set 3 | barh
# Processing Record 48 of Set 3 | ban karon
# Processing Record 49 of Set 3 | iturama
# Processing Record 0 of Set 4 | malango
# Processing Record 1 of Set 4 | wailua homesteads
# Processing Record 2 of Set 4 | kapuskasing
# Processing Record 3 of Set 4 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 4 of Set 4 | santana
# Processing Record 5 of Set 4 | nadym
# Processing Record 6 of Set 4 | kovur
# Processing Record 7 of Set 4 | karwar
# Processing Record 8 of Set 4 | san jose
# Processing Record 9 of Set 4 | tailai
# Processing Record 10 of Set 4 | al 'alamayn
# City not found. Skipping...
# Processing Record 11 of Set 4 | abepura
# Processing Record 12 of Set 4 | gao
# Processing Record 13 of Set 4 | khorixas
# Processing Record 14 of Set 4 | naze
# Processing Record 15 of Set 4 | barreiro do jaiba
# Processing Record 16 of Set 4 | leteri
# Processing Record 17 of Set 4 | hamilton
# Processing Record 18 of Set 4 | brookings
# Processing Record 19 of Set 4 | rio grande
# Processing Record 20 of Set 4 | kailua-kona
# Processing Record 21 of Set 4 | udachny
# Processing Record 22 of Set 4 | ribeira grande
# Processing Record 23 of Set 4 | byron bay
# Processing Record 24 of Set 4 | geraldton
# Processing Record 25 of Set 4 | ilulissat
# Processing Record 26 of Set 4 | ploudalmezeau
# Processing Record 27 of Set 4 | queenstown
# Processing Record 28 of Set 4 | namibe
# Processing Record 29 of Set 4 | plettenberg bay
# Processing Record 30 of Set 4 | codrington
# Processing Record 31 of Set 4 | mukalla
# Processing Record 32 of Set 4 | sao jose da coroa grande
# Processing Record 33 of Set 4 | acapulco de juarez
# Processing Record 34 of Set 4 | waiuku
# Processing Record 35 of Set 4 | susuman
# Processing Record 36 of Set 4 | pont-a-mousson
# Processing Record 37 of Set 4 | uyar
# Processing Record 38 of Set 4 | gobabis
# Processing Record 39 of Set 4 | akobo
# Processing Record 40 of Set 4 | malanje
# Processing Record 41 of Set 4 | altayskoye
# Processing Record 42 of Set 4 | san mariano
# Processing Record 43 of Set 4 | bodo
# Processing Record 44 of Set 4 | tosontsengel
# Processing Record 45 of Set 4 | baruun-urt
# Processing Record 46 of Set 4 | taro
# Processing Record 47 of Set 4 | machali
# Processing Record 48 of Set 4 | tipasa
# Processing Record 49 of Set 4 | inarajan village
# Processing Record 0 of Set 5 | dalai
# Processing Record 1 of Set 5 | vadso
# Processing Record 2 of Set 5 | uglegorsk
# Processing Record 3 of Set 5 | velikiy novgorod
# Processing Record 4 of Set 5 | amla
# Processing Record 5 of Set 5 | mount pearl
# Processing Record 6 of Set 5 | igrim
# Processing Record 7 of Set 5 | pisco
# Processing Record 8 of Set 5 | tinogasta
# Processing Record 9 of Set 5 | minas de marcona
# Processing Record 10 of Set 5 | utrik
# Processing Record 11 of Set 5 | campoverde
# Processing Record 12 of Set 5 | nishinoomote
# Processing Record 13 of Set 5 | hannibal
# Processing Record 14 of Set 5 | mysen
# Processing Record 15 of Set 5 | abashiri
# Processing Record 16 of Set 5 | san antonio de pale
# Processing Record 17 of Set 5 | beni
# Processing Record 18 of Set 5 | fernie
# Processing Record 19 of Set 5 | ghadamis
# Processing Record 20 of Set 5 | ciudad lazaro cardenas
# Processing Record 21 of Set 5 | sao francisco
# Processing Record 22 of Set 5 | colonia
# Processing Record 23 of Set 5 | dorogobuzh
# Processing Record 24 of Set 5 | kristiansund
# Processing Record 25 of Set 5 | sayat
# Processing Record 26 of Set 5 | macapa
# Processing Record 27 of Set 5 | port mathurin
# Processing Record 28 of Set 5 | arkhara
# Processing Record 29 of Set 5 | mogocha
# Processing Record 30 of Set 5 | timbuktu
# Processing Record 31 of Set 5 | seabra
# Processing Record 32 of Set 5 | newman
# Processing Record 33 of Set 5 | mhamid
# Processing Record 34 of Set 5 | barah
# Processing Record 35 of Set 5 | nyurba
# Processing Record 36 of Set 5 | severo-yeniseyskiy
# Processing Record 37 of Set 5 | kenai
# Processing Record 38 of Set 5 | berwick-upon-tweed
# Processing Record 39 of Set 5 | tazacorte
# Processing Record 40 of Set 5 | rikaze
# Processing Record 41 of Set 5 | katsuren-haebaru
# Processing Record 42 of Set 5 | tsiombe
# Processing Record 43 of Set 5 | qaqortoq
# Processing Record 44 of Set 5 | shenjiamen
# Processing Record 45 of Set 5 | redencao
# Processing Record 46 of Set 5 | lyantonde
# Processing Record 47 of Set 5 | bad langensalza
# Processing Record 48 of Set 5 | churapcha
# Processing Record 49 of Set 5 | nemuro
# Processing Record 0 of Set 6 | krosno odrzanskie
# Processing Record 1 of Set 6 | mulchen
# Processing Record 2 of Set 6 | crane
# Processing Record 3 of Set 6 | dompu
# Processing Record 4 of Set 6 | badger
# Processing Record 5 of Set 6 | robore
# Processing Record 6 of Set 6 | nazyvayevsk
# Processing Record 7 of Set 6 | karratha
# Processing Record 8 of Set 6 | kuanda
# Processing Record 9 of Set 6 | urengoy
# Processing Record 10 of Set 6 | chinde
# Processing Record 11 of Set 6 | mahdia
# Processing Record 12 of Set 6 | puerto san carlos
# City not found. Skipping...
# Processing Record 13 of Set 6 | sihanoukville
# Processing Record 14 of Set 6 | devinuwara
# City not found. Skipping...
# Processing Record 15 of Set 6 | kupang
# Processing Record 16 of Set 6 | nova sintra
# Processing Record 17 of Set 6 | wewak
# Processing Record 18 of Set 6 | yung shue wan
# Processing Record 19 of Set 6 | jolo
# Processing Record 20 of Set 6 | forster
# Processing Record 21 of Set 6 | slatina
# Processing Record 22 of Set 6 | port alberni
# Processing Record 23 of Set 6 | novyy urgal
# Processing Record 24 of Set 6 | rancho palos verdes
# Processing Record 25 of Set 6 | ikungi
# Processing Record 26 of Set 6 | xai-xai
# Processing Record 27 of Set 6 | lubang
# Processing Record 28 of Set 6 | la passe
# Processing Record 29 of Set 6 | victorica
# Processing Record 30 of Set 6 | ocean pointe
# City not found. Skipping...
# Processing Record 31 of Set 6 | sinabang
# Processing Record 32 of Set 6 | beira
# Processing Record 33 of Set 6 | tamanrasset
# Processing Record 34 of Set 6 | mamit
# Processing Record 35 of Set 6 | tsiroanomandidy
# Processing Record 36 of Set 6 | constitucion
# Processing Record 37 of Set 6 | konarka
# Processing Record 38 of Set 6 | marsa alam
# Processing Record 39 of Set 6 | tikhvin
# Processing Record 40 of Set 6 | marsh harbour
# Processing Record 41 of Set 6 | pallasovka
# Processing Record 42 of Set 6 | tralee
# Processing Record 43 of Set 6 | ancud
# Processing Record 44 of Set 6 | pasuquin
# Processing Record 45 of Set 6 | tomakivka
# Processing Record 46 of Set 6 | st. john's
# Processing Record 47 of Set 6 | banda aceh
# Processing Record 48 of Set 6 | zhezqazghan
# Processing Record 49 of Set 6 | werdau
# Processing Record 0 of Set 7 | corinto
# Processing Record 1 of Set 7 | anadyr
# Processing Record 2 of Set 7 | castillos
# Processing Record 3 of Set 7 | porto novo
# Processing Record 4 of Set 7 | roma
# Processing Record 5 of Set 7 | asola
# Processing Record 6 of Set 7 | huron
# Processing Record 7 of Set 7 | sao felix do xingu
# Processing Record 8 of Set 7 | mar del plata
# Processing Record 9 of Set 7 | suva
# Processing Record 10 of Set 7 | alexandria
# Processing Record 11 of Set 7 | klaksvik
# Processing Record 12 of Set 7 | ciudad bolivar
# Processing Record 13 of Set 7 | peraia
# Processing Record 14 of Set 7 | isiro
# Processing Record 15 of Set 7 | ola
# Processing Record 16 of Set 7 | sambava
# Processing Record 17 of Set 7 | catalao
# Processing Record 18 of Set 7 | kitimat
# Processing Record 19 of Set 7 | afaahiti
# Processing Record 20 of Set 7 | la sarre
# Processing Record 21 of Set 7 | northam
# Processing Record 22 of Set 7 | kargil
# Processing Record 23 of Set 7 | monroeville
# Processing Record 24 of Set 7 | cargados carajos
# City not found. Skipping...
# Processing Record 25 of Set 7 | eydhafushi
# Processing Record 26 of Set 7 | aleg
# Processing Record 27 of Set 7 | tokar
# Processing Record 28 of Set 7 | nchelenge
# Processing Record 29 of Set 7 | manismata
# Processing Record 30 of Set 7 | gunjur
# Processing Record 31 of Set 7 | tahara
# Processing Record 32 of Set 7 | loch garman
# Processing Record 33 of Set 7 | grants
# Processing Record 34 of Set 7 | bardai
# Processing Record 35 of Set 7 | villa union
# Processing Record 36 of Set 7 | rijau
# Processing Record 37 of Set 7 | grahamstown
# Processing Record 38 of Set 7 | grand falls-windsor
# Processing Record 39 of Set 7 | rajapur
# Processing Record 40 of Set 7 | marion
# Processing Record 41 of Set 7 | jhunjhunun
# Processing Record 42 of Set 7 | antsiranana
# Processing Record 43 of Set 7 | hadibu
# Processing Record 44 of Set 7 | fuglafjordur
# Processing Record 45 of Set 7 | veraval
# Processing Record 46 of Set 7 | bubaque
# Processing Record 47 of Set 7 | puerto baquerizo moreno
# Processing Record 48 of Set 7 | berbera
# Processing Record 49 of Set 7 | aliade
# Processing Record 0 of Set 8 | freetown
# Processing Record 1 of Set 8 | nova vicosa
# Processing Record 2 of Set 8 | ibiza
# Processing Record 3 of Set 8 | vorgashor
# Processing Record 4 of Set 8 | san patricio
# Processing Record 5 of Set 8 | vrede
# Processing Record 6 of Set 8 | howrah
# Processing Record 7 of Set 8 | ishigaki
# Processing Record 8 of Set 8 | sadjoavato
# City not found. Skipping...
# Processing Record 9 of Set 8 | floro
# Processing Record 10 of Set 8 | tranovaho
# City not found. Skipping...
# Processing Record
# Processing Record 35 of Set 9 | sabana de torres
# Processing Record 36 of Set 9 | abengourou
# Processing Record 37 of Set 9 | rongelap
# Processing Record 38 of Set 9 | conception bay south
# Processing Record 39 of Set 9 | selfoss
# Processing Record 40 of Set 9 | portstewart
# Processing Record 41 of Set 9 | makurazaki
# Processing Record 42 of Set 9 | lompoc
# Processing Record 43 of Set 9 | turan
# Processing Record 44 of Set 9 | san-pedro
# Processing Record 45 of Set 9 | northampton
# Processing Record 46 of Set 9 | gangtok
# Processing Record 47 of Set 9 | madimba
# Processing Record 48 of Set 9 | karamay
# City not found. Skipping...
# Processing Record 49 of Set 9 | port-cartier
# Processing Record 0 of Set 10 | divaca
# Processing Record 1 of Set 10 | cinisi
# Processing Record 2 of Set 10 | naberera
# Processing Record 3 of Set 10 | rabigh
# Processing Record 4 of Set 10 | puerto aysen
# Processing Record 5 of Set 10 | mabaruma
# Processing Record 6 of Set 10 | luba
# Processing Record 7 of Set 10 | kingston
# Processing Record 8 of Set 10 | lionel town
# Processing Record 9 of Set 10 | basco
# Processing Record 10 of Set 10 | garachico
# Processing Record 11 of Set 10 | podporozh'ye
# Processing Record 12 of Set 10 | kourou
# Processing Record 13 of Set 10 | gazojak
# Processing Record 14 of Set 10 | nabire
# Processing Record 15 of Set 10 | camocim
# Processing Record 16 of Set 10 | beloyarskiy
# Processing Record 17 of Set 10 | alo
# Processing Record 18 of Set 10 | 'ohonua
# City not found. Skipping...
# Processing Record 19 of Set 10 | zhuji
# Processing Record 20 of Set 10 | nizhniy kuranakh
# Processing Record 21 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 22 of Set 10 | weno
# Processing Record 23 of Set 10 | camana
# Processing Record 24 of Set 10 | badhni kalan
# Processing Record 25 of Set 10 | la junta
# Processing Record 26 of Set 10 | ventspils
# Processing Record 27 of Set 10 | usogorsk
# Processing Record 28 of Set 10 | la'ie
# Processing Record 29 of Set 10 | namtsy
# Processing Record 30 of Set 10 | haiku-pauwela
# Processing Record 31 of Set 10 | micheweni
# Processing Record 32 of Set 10 | holualoa
# Processing Record 33 of Set 10 | scarborough
# Processing Record 34 of Set 10 | jabat
# Processing Record 35 of Set 10 | kavaratti
# Processing Record 36 of Set 10 | okhotsk
# Processing Record 37 of Set 10 | dhidhdhoo
# Processing Record 38 of Set 10 | imperatriz
# Processing Record 39 of Set 10 | nurlat
# Processing Record 40 of Set 10 | santa cruz
# Processing Record 41 of Set 10 | krishnarajpet
# Processing Record 42 of Set 10 | debre tabor
# Processing Record 43 of Set 10 | morondava
# Processing Record 44 of Set 10 | belel
# Processing Record 45 of Set 10 | lata
# Processing Record 46 of Set 10 | couzeix
# Processing Record 47 of Set 10 | ndele
# Processing Record 48 of Set 10 | revda
# Processing Record 49 of Set 10 | al kharijah
# Processing Record 0 of Set 11 | igarka
# Processing Record 1 of Set 11 | bom jesus
# Processing Record 2 of Set 11 | aykhal
# Processing Record 3 of Set 11 | cabanas
# Processing Record 4 of Set 11 | san antonio del estrecho
# City not found. Skipping...
# Processing Record 5 of Set 11 | selkirk
# Processing Record 6 of Set 11 | ain leuh
# Processing Record 7 of Set 11 | opuwo
# Processing Record 8 of Set 11 | urbana
# Processing Record 9 of Set 11 | pavlovka
# Processing Record 10 of Set 11 | roschinskiy
# Processing Record 11 of Set 11 | sinop
# Processing Record 12 of Set 11 | ornskoldsvik
# Processing Record 13 of Set 11 | mujiayingzi
# Processing Record 14 of Set 11 | beboto
# Processing Record 15 of Set 11 | qal'at bishah
# City not found. Skipping...
# Processing Record 16 of Set 11 | sao joao da barra
# Processing Record 17 of Set 11 | prince george
# Processing Record 18 of Set 11 | genc
# Processing Record 19 of Set 11 | tucumcari
# Processing Record 20 of Set 11 | murud
# Processing Record 21 of Set 11 | kas
# Processing Record 22 of Set 11 | benghazi
# Processing Record 23 of Set 11 | uturoa
# Processing Record 24 of Set 11 | gebeit
# Processing Record 25 of Set 11 | gore
# Processing Record 26 of Set 11 | arys
# Processing Record 27 of Set 11 | daru
# Processing Record 28 of Set 11 | talara
# Processing Record 29 of Set 11 | murun-kuren
# Processing Record 30 of Set 11 | mezhdurechenskiy
# Processing Record 31 of Set 11 | mount gambier
# Processing Record 32 of Set 11 | avila
# Processing Record 33 of Set 11 | east london
# Processing Record 34 of Set 11 | la ronge
# Processing Record 35 of Set 11 | chos malal
# Processing Record 36 of Set 11 | andorra
# Processing Record 37 of Set 11 | mpika
# Processing Record 38 of Set 11 | portland
# Processing Record 39 of Set 11 | kalabo
# Processing Record 40 of Set 11 | santa elena de uairen
# Processing Record 41 of Set 11 | quatre cocos
# Processing Record 42 of Set 11 | pacasmayo
# Processing Record 43 of Set 11 | mizdah
# Processing Record 44 of Set 11 | vanino
# Processing Record 45 of Set 11 | ozieri
# Processing Record 46 of Set 11 | ulsteinvik
# Processing Record 47 of Set 11 | torteval
# City not found. Skipping...
# Processing Record 48 of Set 11 | el colorado
# Processing Record 49 of Set 11 | horsham
# Processing Record 0 of Set 12 | arno
# Processing Record 1 of Set 12 | island harbour
# Processing Record 2 of Set 12 | takanabe
# Processing Record 3 of Set 12 | taslicay
# Processing Record 4 of Set 12 | isle of lewis
# City not found. Skipping...
# Processing Record 5 of Set 12 | aksu
# Processing Record 6 of Set 12 | ismailia
# Processing Record 7 of Set 12 | cabo san lucas
# Processing Record 8 of Set 12 | hluti
# Processing Record 9 of Set 12 | ain sukhna
# Processing Record 10 of Set 12 | colac
# Processing Record 11 of Set 12 | archangelos
# Processing Record 12 of Set 12 | ahau
# City not found. Skipping...
# Processing Record 13 of Set 12 | la malbaie
# Processing Record 14 of Set 12 | sakaiminato
# Processing Record 15 of Set 12 | ouesso
# Processing Record 16 of Set 12 | ponta delgada
# Processing Record 17 of Set 12 | carnarvon
# Processing Record 18 of Set 12 | aberdeen
# Processing Record 19 of Set 12 | can tho
# Processing Record 20 of Set 12 | ballina
# Processing Record 21 of Set 12 | ibshaway
# Processing Record 22 of Set 12 | angaur state
# Processing Record 23 of Set 12 | caleta de carquin
# Processing Record 24 of Set 12 | vylkove
# Processing Record 25 of Set 12 | baoshan
# Processing Record 26 of Set 12 | nea alikarnassos
# Processing Record 27 of Set 12 | sarykemer
# Processing Record 28 of Set 12 | cocal
# Processing Record 29 of Set 12 | gonzales
# Processing Record 30 of Set 12 | sonsorol village
# City not found. Skipping...
# Processing Record 31 of Set 12 | ha'il
# Processing Record 32 of Set 12 | n'zeto
# Processing Record 33 of Set 12 | pendleton
# Processing Record 34 of Set 12 | lashkar gah
# Processing Record 35 of Set 12 | rawson
# Processing Record 36 of Set 12 | pierre
# Processing Record 37 of Set 12 | acajutla
# Processing Record 38 of Set 12 | topolobampo
# Processing Record 39 of Set 12 | nuuk
# Processing Record 40 of Set 12 | hithadhoo
# Processing Record 41 of Set 12 | kataragama
# City not found. Skipping...
# Processing Record 42 of Set 12 | simanggang
# Processing Record 43 of Set 12 | isangel
# Processing Record 44 of Set 12 | lyubymivka
# Processing Record 45 of Set 12 | hilo
# Processing Record 46 of Set 12 | soure
# Processing Record 47 of Set 12 | sungai penuh
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          569
# Lat           569
# Lng           569
# Max Temp      569
# Humidity      569
# Cloudiness    569
# Wind Speed    569
# Country       569
# Date          569
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           waitangi -43.9535 -176.5597     14.34        95         100
# 1           felanitx  39.4696    3.1483     13.29        64         100
# 2         bredasdorp -34.5322   20.0403     18.34        82         100
# 3  port-aux-francais -49.3500   70.2167      5.20        90         100
# 4              tiksi  71.6872  128.8694    -28.65        98          99
#
#    Wind Speed Country        Date
# 0        2.24      NZ  1711482336
# 1        8.34      ES  1711482336
# 2        5.57      ZA  1711482337
# 3       15.29      TF  1711482338
# 4        3.56      RU  1711482338

# %%
# Export the City_Data into a csv
city_data_df.to_csv("/Users/Joyjo/OneDrive/Documents/GitHub/python-api-challenge/output_data, index_label=City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("/Users/Joyjo/OneDrive/Documents/GitHub/python-api-challenge/output_data, index_label=City_ID")

# Display sample data
city_data_df.head()
# Out:
#    Unnamed: 0               City      Lat       Lng  Max Temp  Humidity  \
# 0           0           waitangi -43.9535 -176.5597     14.34        95
# 1           1           felanitx  39.4696    3.1483     13.29        64
# 2           2         bredasdorp -34.5322   20.0403     18.34        82
# 3           3  port-aux-francais -49.3500   70.2167      5.20        90
# 4           4              tiksi  71.6872  128.8694    -28.65        98
#
#    Cloudiness  Wind Speed Country        Date
# 0         100        2.24      NZ  1711482336
# 1         100        8.34      ES  1711482336
# 2         100        5.57      ZA  1711482337
# 3         100       15.29      TF  1711482338
# 4          99        3.56      RU  1711482338

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], edgecolors="blue", alpha=0.75)

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Max Temperature (Date: {city_data_df['Date'].iloc[0]})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (°C)")
plt.grid(True)

# Save the figure
plt.savefig("/Users/Joyjo/OneDrive/Documents/GitHub/python-api-challenge/output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], edgecolors="blue", alpha=0.75)

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Humidity (Date: {city_data_df['Date'].iloc[0]})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

# Save the figure
plt.savefig("/Users/Joyjo/OneDrive/Documents/GitHub/python-api-challenge/output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], edgecolors="blue", alpha=0.75)

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Cloudiness (Date: {city_data_df['Date'].iloc[0]})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)

# Save the figure
plt.savefig("/Users/Joyjo/OneDrive/Documents/GitHub/python-api-challenge/output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], edgecolors="blue", alpha=0.75)

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Wind Speed (Date: {city_data_df['Date'].iloc[0]})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.grid(True)

# Save the figure
plt.savefig("/Users/Joyjo/OneDrive/Documents/GitHub/python-api-challenge/output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, xlabel, ylabel, title):
    # Perform linear regression
    slope, intercept, rvalue, pvalue, stderr = linregress(x_values, y_values)
    
    # Get regression values
    regress_values = x_values * slope + intercept
    
    # Plot scatter plot
    plt.scatter(x_values, y_values)
    
    # Plot regression line
    plt.plot(x_values, regress_values, "r-")
    
    # Create line equation string and annotate
    line_eq = f'y = {round(slope, 2)}x + {round(intercept, 2)}'
    plt.annotate(line_eq, (min(x_values), min(y_values)), fontsize=12, color="deeppink")
    
    # Label plot
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    
    # Show plot
    plt.show()

# Call the function to plot linear regression for temperature vs. latitude
plot_linear_regression(city_data_df["Lat"], city_data_df["Max Temp"], "Latitude", "Max Temperature (°C)", "City Latitude vs. Max Temperature")

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#    Unnamed: 0                      City      Lat       Lng  Max Temp  \
# 1           1                  felanitx  39.4696    3.1483     13.29
# 4           4                     tiksi  71.6872  128.8694    -28.65
# 5           5                    saipan  15.1355  145.7010     26.39
# 8           8  petropavlovsk-kamchatsky  53.0452  158.6483     -4.67
# 9           9                   aasiaat  68.7098  -52.8699     -6.28
#
#    Humidity  Cloudiness  Wind Speed Country        Date
# 1        64         100        8.34      ES  1711482336
# 4        98          99        3.56      RU  1711482338
# 5         1          40        4.12      MP  1711482339
# 8        58          75        3.00      RU  1711482341
# 9        89         100        4.43      GL  1711482341

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#    Unnamed: 0                         City      Lat       Lng  Max Temp  \
# 0           0                     waitangi -43.9535 -176.5597     14.34
# 2           2                   bredasdorp -34.5322   20.0403     18.34
# 3           3            port-aux-francais -49.3500   70.2167      5.20
# 6           6  edinburgh of the seven seas -37.0676  -12.3116     17.26
# 7           7                  broken hill -31.9500  141.4333     16.06
#
#    Humidity  Cloudiness  Wind Speed Country        Date
# 0        95         100        2.24      NZ  1711482336
# 2        82         100        5.57      ZA  1711482337
# 3        90         100       15.29      TF  1711482338
# 6        75         100        6.12      SH  1711482339
# 7        43          72        4.77      AU  1711482340

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Perform linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot linear regression
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq, (2, -10), fontsize=15, color="deeppink")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (°C)")  # Adjust ylabel based on the weather variable you are analyzing
plt.title("Northern Hemisphere - Max Temperature vs. Latitude Linear Regression")
plt.grid(True)
plt.show()

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]  

# Perform linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Calculate regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot linear regression
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq, (-50, 35), fontsize=15, color="deeppink")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (°C)") 
plt.title("Southern Hemisphere - Max Temperature vs. Latitude Linear Regression")
plt.grid(True)
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** the linear regression help shows the prediction of temperatures and how it variesw for each i notice that the southern hemisphere is positive and northern is negative maybe this correlates to seasons.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
northern_hemi_df = city_data_df[city_data_df["Lat"] >= 0]

# Plot scatter plot
plt.scatter(northern_hemi_df["Lat"], northern_hemi_df["Humidity"], edgecolors="blue", alpha=0.75)

# Perform linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(northern_hemi_df["Lat"], northern_hemi_df["Humidity"])
regress_values = northern_hemi_df["Lat"] * slope + intercept

# Plot regression line
plt.plot(northern_hemi_df["Lat"], regress_values, "r-")

# Annotate
plt.annotate(f'y = {round(slope, 2)}x + {round(intercept, 2)}', (min(northern_hemi_df["Lat"]), min(northern_hemi_df["Humidity"])), fontsize=12, color="red")

# Plot
plt.title("Northern Hemisphere - Humidity vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

# Show plot
plt.show()

# %%
# Southern Hemisphere
southern_hemi_df = city_data_df[city_data_df["Lat"] < 0]

# Plot scatter plot
plt.scatter(southern_hemi_df["Lat"], southern_hemi_df["Humidity"], edgecolors="blue", alpha=0.75)

# Perform linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(southern_hemi_df["Lat"], southern_hemi_df["Humidity"])
regress_values = southern_hemi_df["Lat"] * slope + intercept

# Plot regression line
plt.plot(southern_hemi_df["Lat"], regress_values, "r-")

# Annotate
plt.annotate(f'y = {round(slope, 2)}x + {round(intercept, 2)}', (min(southern_hemi_df["Lat"]), min(southern_hemi_df["Humidity"])), fontsize=12, color="red")

# Add labels and title
plt.title("Southern Hemisphere - Humidity vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

# Show plot
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** it does not look like humididy has much correlation with lat, humitdity is higher in southern hempisphere

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
(slope, intercept, rvalue, pvalue, stderr) = linregress(northern_hemi_df["Lat"], northern_hemi_df["Cloudiness"])

# Get regression values
regress_values = northern_hemi_df["Lat"] * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create scatter plot
plt.scatter(northern_hemi_df["Lat"], northern_hemi_df["Cloudiness"])

# Plot regression line
plt.plot(northern_hemi_df["Lat"], regress_values, "r-")

# Annotate
plt.annotate(line_eq, (10,40), fontsize=15, color="red")

# Label plot
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("Northern Hemisphere - Cloudiness vs. Latitude Linear Regression")

# Print r-value
print(f"The r-value is: {rvalue}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.19908378186425713

# %%
# Southern Hemisphere
(slope, intercept, rvalue, pvalue, stderr) = linregress(southern_hemi_df["Lat"], southern_hemi_df["Cloudiness"])

# Get regression values
regress_values = southern_hemi_df["Lat"] * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create scatter plot
plt.scatter(southern_hemi_df["Lat"], southern_hemi_df["Cloudiness"])

# Plot regression line
plt.plot(southern_hemi_df["Lat"], regress_values, "r-")

# Annotate
plt.annotate(line_eq, (-50,60), fontsize=15, color="red")

# Label plot
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("Southern Hemisphere - Cloudiness vs. Latitude Linear Regression")

# Print r-value
print(f"The r-value is: {rvalue}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.1973856605117335

# %% [markdown]
# **Discussion about the linear relationship:** shows no valuable correleation

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]

# Perform linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create equation of the line
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")

# Annotate
plt.annotate(line_eq,(0,0),fontsize=15,color="red")

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.title('Northern Hemisphere - Wind Speed vs. Latitude Linear Regression')

# Print r-value
print(f"The r-value is: {rvalue}")

# Show plot
plt.show()
# Out:
# The r-value is: -0.01935964318144269

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]

# Perform linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create equation of the line
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")

# Annotate
plt.annotate(line_eq,(-50,9),fontsize=15,color="red")

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.title('Southern Hemisphere - Wind Speed vs. Latitude Linear Regression')

# Print r-value
print(f"The r-value is: {rvalue}")

# Show plot
plt.show()
# Out:
# The r-value is: -0.32934764492468094

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %%
#no close relation except southern when you enge closer to 0 lat
